# %%
import requests
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/115.0"
}
r = requests.get("https://www.knack.be/news-sitemap.xml", headers=HEADERS)
print(r.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <?xml-stylesheet type="text/xsl" href="https://www.knack.be/news-sitemap.xsl"?>
# <urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9" xmlns:news="http://www.google.com/schemas/sitemap-news/0.9">
# <url>
# 	<loc>https://www.knack.be/nieuws/belgie/er-wordt-nog-te-vaak-gedaan-alsof-extra-salaris-een-beroep-plots-interessant-maakt/</loc>
# 	<news:news>
# 		<news:publication>
# 			<news:name></news:name>
# 			<news:language>nl</news:language>
# 		</news:publication>
# 		<news:publication_date>2023-08-02T14:00:00+00:00</news:publication_date>
# 		<news:title><![CDATA[&#8216;Er wordt nog te vaak gedaan alsof extra salaris een beroep plots interessant maakt&#8217;]]></news:title>
# 	</news:news>
# </url>
# <url>
# 	<loc>https://www.knack.be/nieuws/wereld/europa/baltische-staten-willen-stroomnet-volledig-loskoppelen-van-rusland/</loc>
# 	<news:news>
# 		<news:publication>
# 			<news:name></news:name>
# 			<news:language>nl</news:language>
# ...

# %%
sitemaps = pd.read_xml(r.text)
sitemaps.head()
# Out:
#                                                  loc  news
# 0  https://www.knack.be/nieuws/belgie/er-wordt-no...   NaN
# 1  https://www.knack.be/nieuws/wereld/europa/balt...   NaN
# 2  https://www.knack.be/nieuws/wereld/trumps-kies...   NaN
# 3  https://www.knack.be/nieuws/belgie/maatschappi...   NaN
# 4  https://www.knack.be/nieuws/belgie/politiek/ba...   NaN

# %%
urls = sitemaps["loc"]
print(urls)
# Out:
# 0     https://www.knack.be/nieuws/belgie/er-wordt-no...
# 1     https://www.knack.be/nieuws/wereld/europa/balt...
# 2     https://www.knack.be/nieuws/wereld/trumps-kies...
# 3     https://www.knack.be/nieuws/belgie/maatschappi...
# 4     https://www.knack.be/nieuws/belgie/politiek/ba...
# 5     https://www.knack.be/nieuws/wereld/trump-aange...
# 6     https://www.knack.be/nieuws/belgie/de-miljoene...
# 7     https://www.knack.be/nieuws/belgie/stop-met-ca...
# 8     https://www.knack.be/sport/wielrennen/zestig-j...
# 9     https://www.knack.be/nieuws/belgie/vertraging-...
# 10    https://www.knack.be/nieuws/belgie/hoe-erg-is-...
# 11    https://www.knack.be/nieuws/wereld/staatsgreep...
# 12    https://www.knack.be/nieuws/belgie/politiek/ve...
# 13    https://www.knack.be/nieuws/belgie/politiek/ge...
# 14    https://www.knack.be/nieuws/belgie/politiek/de...
# 15    https://www.knack.be/nieuws/cultuur/laat-de-ku...
# 16    https://www.knack.be/nieuws/auto/mercedes-v-kl...
# ...

# %%
url = urls[0]
response = requests.get(url, headers = HEADERS).text
print(response)
# Out:
# <!doctype html>
# <!--[if lt IE 9]><html class="no-js no-svg ie lt-ie9 lt-ie8 lt-ie7" lang="nl"> <![endif]-->
# <!--[if IE 9]><html class="no-js no-svg ie ie9 lt-ie9 lt-ie8" lang="nl"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js no-svg" lang="nl"> <!--<![endif]-->
# <head>
#             <meta charset="UTF-8"/>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# ...

# %%
soup = BeautifulSoup(response, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 9]><html class="no-js no-svg ie lt-ie9 lt-ie8 lt-ie7" lang="nl"> <![endif]-->
# <!--[if IE 9]><html class="no-js no-svg ie ie9 lt-ie9 lt-ie8" lang="nl"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js no-svg" lang="nl"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# ...

# %%
title = soup.find("h1").text
print(title)
# Out:
# ‘Er wordt nog te vaak gedaan alsof extra salaris een beroep plots interessant maakt’

# %%
article = soup.find_all("p", attrs={"class": None})
articles = [p.text for p in article]
cleaned_articles = " ".join(articles)
print(cleaned_articles)
# Out:
# Als we nadenken over arbeidsmarkthervormingen, dan is het wegwerken van ongelijkheden misschien wel de eerste stap. Een van die ongelijkheden is de inkomensongelijkheid.  Er wordt vaak beweerd dat arbeid onvoldoende loont, maar die generalisatie doet geen recht aan de realiteit. Volgens cijfers van Statbel lag het modaal inkomen in 2020 rond de 3.500 euro bruto, terwijl managers al snel het dubbele verdienen. Schoonmakers, kappers en barpersoneel verdienen daarentegen gemiddeld minder dan 2.500 euro bruto per maand.  In plaats van te streven naar een evenredige salarisverhoging voor iedereen, zouden we ervoor moeten zorgen dat de salarissen altijd voor iedereen leefbaar, en voor niemand exorbitant zijn. Bovendien moet er meer gekeken worden naar de maatschappelijke impact van arbeid. De huidige verloning van arbeid verschilt namelijk niet enkel veel tussen beroepen en sectoren, maar correspondeert ook niet met de maatschappelijke impact.  Een voorbeeld. Mantelzorg is waardevol voor d
# ...

# %%
meta = soup.find("meta", property="article:published_time")
published_date = meta["content"]
print(published_date)
# Out:
# 2023-08-02T14:00:00+00:00
